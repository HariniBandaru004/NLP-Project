# %%
import pandas as pd

# %%
n_dataset=pd.read_csv("big.txt",sep='delimiter',engine='python')

# %%
print(n_dataset)
# Out:
#          $Albert
# 0             Ab
# 1       $America
# 2        Ameraca
# 3        Amercia
# 4      $American
# ...          ...
# 42263       yuth
# 42264   $zealous
# 42265     zelous
# 42266    $zenith
# 42267    zeenith
#
# [42268 rows x 1 columns]

# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
    with open(filename, "r") as file:
        lines = file.readlines()
        words = []
        for line in lines:
            words += re.findall(r'\w+', line.lower())
        return words

# %%
words = read_corpus("./big.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 42699 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 38641 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["list"])
# Out:
# 2

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["list"])
# Out:
# 4.683950443804304e-05

# %%
def split(word):
    return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
def delete(word):
    return [l + r[1:] for l,r in split(word) if r]

# %%
def swap(word):
    return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
    letters = string.ascii_lowercase
    return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
    letters = string.ascii_lowercase
    return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def edit1(word):
    return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'tresh', 'utrash', 'torash', 'trasmh', 'trasc', 'trahh', 'mrash', 'teash', 'tdash', 'trpsh', 'traph', 'rtrash', 'trxash', 'travsh', 'ptrash', 'trasgh', 'yrash', 'trasbh', 'tradsh', 'ktrash', 'thrash', 'htrash', 'trpash', 'gtrash', 'tzrash', 'tramsh', 'trashl', 'trashx', 'otrash', 'txrash', 'trajh', 'trasuh', 'trasb', 'trasr', 'trjash', 'trashw', 'traush', 'tjash', 'tragsh', 'etrash', 'trasa', 'transh', 'tzash', 'trach', 'treash', 'traksh', 'tramh', 'trashs', 'mtrash', 'trashy', 'taash', 'ztrash', 'trwsh', 'trzsh', 'trashd', 'trasj', 'trosh', 'drash', 'trqsh', 'trlash', 'trazh', 'trmsh', 'traish', 'ctrash', 'trashm', 'trashu', 'trgsh', 'trask', 'ttash', 'tgrash', 'turash', 'tyrash', 'trasph', 'trsh', 'irash', 'tyash', 'trasdh', 'traszh', 'trasht', 'traso', 'jtrash', 'traesh', 'trah', 'trasz', 'vrash', 'travh', 'wrash', 'itrash', 'xrash', 'trvsh', 'trarsh', 'trasqh', 'trashb', 'crash', 'tjrash', 'traslh', 'erash', 'grash', 'trajsh', 'nrash', 'trhsh', 'arash', 'twash', 'trlsh', 'trast', 'tqrash', 'urash', 'trcsh', 'trhash', 'tlash', 'trkash', 'truash', 'trapsh', 'thash', 'traysh', 'trasvh', 'trbash', 'tlrash', 'trcash', 'trmash', 'traih', 'tgash', 'traeh', 'trayh', 'terash', 'trashi', 'tdrash', 'tracsh', 'trasah', 'traswh', 'trjsh', 'brash', 'lrash', 'trarh', 'tiash', 'trasn', 'dtrash', 'tralh', 'trawsh', 'tranh', 'trasv', 'tryash', 'trasho', 'tpash', 'trasp', 'tfrash', 'trgash', 'srash', 'trasjh', 'trazsh', 'rtash', 'trasf', 'trasl', 'trasx', 'traqh', 'krash', 'orash', 'trahsh', 'traxsh', 'tsash', 'trqash', 'trashr', 'trahs', 'zrash', 'tralsh', 'strash', 'trawh', 'trasch', 'qrash', 'trksh', 'trafsh', 'trasyh', 'trasih', 'frash', 'trtsh', 'trakh', 'trashk', 'tuash', 'trashj', 'atrash', 'tvash', 'trtash', 'trasrh', 'trnash', 'trasg', 'trashc', 'trvash', 'trasth', 'tqash', 'trish', 'triash', 'trashg', 'tnrash', 'tprash', 'troash', 'trauh', 'trashq', 'tradh', 'tfash', 'tarash', 'xtrash', 'trash', 'ntrash', 'traskh', 'toash', 'txash', 'traah', 'trase', 'trashf', 'ftrash', 'traosh', 'btrash', 'trath', 'trasm', 'trfash', 'trzash', 'trashn', 'traqsh', 'trashh', 'jrash', 'trfsh', 'trush', 'tmash', 'tragh', 'trxsh', 'qtrash', 'ttrash', 'vtrash', 'tirash', 'traseh', 'trdsh', 'trnsh', 'tratsh', 'prash', 'trashe', 'tbash', 'tnash', 'trass', 'hrash', 'trysh', 'tash', 'trasy', 'trasxh', 'tcash', 'trssh', 'trafh', 'trasq', 'rrash', 'trdash', 'traash', 'trbsh', 'trasw', 'twrash', 'ltrash', 'traxh', 'trashp', 'tkrash', 'trsah', 'tvrash', 'trasoh', 'tras', 'trrash', 'trrsh', 'trassh', 'trasu', 'trasha', 'rash', 'trashz', 'trashv', 'tcrash', 'trwash', 'trasfh', 'trasd', 'trsash', 'wtrash', 'traoh', 'trasnh', 'trabsh', 'tsrash', 'trasi', 'tbrash', 'tarsh', 'trabh', 'tmrash', 'tkash', 'ytrash'}

# %%
def edit2(word):
    return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'trtosh', 'btrashr', 'trasghc', 'trlashe', 'irasth', 'trashdj', 'erashd', 'tryuash', 'tbrrsh', 'grgash', 'xtraso', 'nrfsh', 'ontrash', 'trcsz', 'tusrash', 'terasvh', 'tarasnh', 'tqasho', 'twahh', 'tuqsh', 'crasx', 'trassmh', 'wramsh', 'traismh', 'trnhash', 'trdasr', 'tmramh', 'trcshw', 'tjerash', 'travash', 'tpafh', 'trazseh', 'twrath', 'trtpsh', 'tlrqsh', 'trasjhi', 'trawgh', 'ltrasr', 'wtrdsh', 'torkash', 'astrash', 'rtrashk', 'twasnh', 'tyrasc', 'tqratsh', 'tradhx', 'trkasw', 'tuasah', 'ltwrash', 'hrakh', 'trzasm', 'trpcash', 'trasuc', 'trakosh', 'ftrahh', 'tbaesh', 'trvashb', 'thrbsh', 'tyashs', 'tprasht', 'traggh', 'zrashl', 'trabsa', 'tralsch', 'tyrrsh', 'yryash', 'trfabh', 'trxysh', 'trasnp', 'bmash', 'trascb', 'traxsgh', 'hrazh', 'tkashq', 'gtrashl', 'vrazh', 'krashd', 'itriash', 'trysn', 'tmgsh', 'htrasdh', 'ftrakh', 'trdsi', 'trawhh', 'drashl', 'etrasb', 'utrmash', 'tirashd', 'tyaesh', 'truysh', 'rtraso', 'trashnh', 'tramksh', 'ptfash', 'tsrhash', 'trhsash', 'trdsoh', 'tbrabh', 'tpasuh', 'wtraxsh', 'trtshw', 'trhshu', 'troasa', 'vrayh', 'oqash', 'srasha', 'trahwsh', 'crafsh', 'qraskh', 'gtrasl', 'mrasha', 'trbshk', 'talsh', 'taath', 'vtrmsh', 'orasw', 'btrase', 'trwasjh', 'ttrashz', 'rtrashj', 'tdrrash', 'rtawh', 'tqrashm', 'erasf', 'ntresh', 'trhesh', 'tguash', 'trasqw', 'tzaph', 'wtriash', 'trafa', 'uwtrash', 'wrafsh', 'trgasu', 'tfabsh', 'trawih', 'teask', 'tsasnh', 'lrgsh', 'txrasi', 'trvasmh', 'urhash', 'tratjsh', 'utarsh', 'yragh', 'xransh', 'tmaqh', 'tvase', 'atras', 'totrash', 'tirashp', 'terajsh', 'tcgash', 'trasnjh', 'tfauh', 'trkashw', 'trsr', 'truajsh', 'trakss', 'troazh', 'ntrasph', 'cterash', 'truashe', 'ftarsh', 'tracskh', 'trfashd', 'tratskh', 'turahh', 'travgsh', 'transw', 'trrashq', 'xrasyh', 'trsarsh', 'terpsh', 'tkasq', 'trahhm', 'ktxash', 'twrpash', 'tvzsh', 'tykash', 'trlshg', 'frarh', 'eiash', 'lkash', 'ptvrash', 'ytrasfh', 'tnaish', 'traprh', 'htraish', 'truashb', 'tvrtsh', 'txaah', 'xtrasch', 'troashi', 'dtraysh', 'arsh', 'trxshx', 'trlhash', 'tzrashn', 'trasmv', 'trashlx', 'prafsh', 'stlash', 'ltrasuh', 'orach', 'trasai', 'gtrass', 'ftrahs', 'tzasy', 'tpsrash', 'toas', 'traesu', 'etrrsh', 'trlshz', 'tjasth', 'trtshq', 'qrashl', 'trfss', 'atbash', 'trashny', 'xturash', 'urashe', 'tchash', 'trasmhs', 'turasq', 'rtuash', 'trmah', 'turashl', 'traeshx', 'trysgh', 'trsabh', 'tyrarsh', 'trusash', 'ntrmsh', 'tfrcash', 'rrabh', 'traghl', 'trassf', 'xtrahs', 'tcxsh', 'trauuh', 'trasohv', 'vrasz', 'trmashv', 'trsjh', 'vtraosh', 'trcszh', 'twraeh', 'trjaso', 'tdrashs', 'tarshn', 'mtrajsh', 'traksbh', 'travih', 'trvashm', 'trraph', 'trgdh', 'ararh', 'trqrsh', 'iurash', 'tgasy', 'tscsh', 'tdxsh', 'terashy', 'trkaih', 'fsrash', 'shrash', 'trapsmh', 'teavsh', 'krasnh', 'trqaosh', 'grlash', 'trmsth', 'thtsh', 'tlrafh', 'tkashv', 'trnagh', 'tstash', 'ftrabh', 'ntrasq', 'trxajh', 'rrasah', 'trrsi', 'traku', 'spash', 'utyash', 'otrtash', 'trvavh', 'tpragsh', 'mrasi', 'tragkh', 'sntrash', 'trashjp', 'lrbash', 'ftrasnh', 'trashgn', 'trmasi', 'tdaeh', 'tmprash', 'traswvh', 'tdsah', 'tahsh', 'traskah', 'tramhw', 'oetrash', 'rtasqh', 'erpash', 'trpsy', 'thrafh', 'trashaf', 'tramsah', 'trauk', 'trkeash', 'teaswh', 'tlashz', 'tqrashk', 'teerash', 'trfabsh', 'turasz', 'trfatsh', 'urasz', 'gtransh', 'trjashm', 'utkrash', 'wrasw', 'frasi', 'trfksh', 'tkrasp', 'tmasqh', 'trtst', 'trashzg', 'traso', 'nxtrash', 'irtrash', 'iltrash', 'tralhg', 'trapshe', 'trkso', 'tralhu', 'trasiho', 'kqash', 'trcyash', 'tsrashw', 'twrasi', 'gtrashz', 'tzrashd', 'trxnash', 'trcsash', 'trasthg', 'thrase', 'zbash', 'oraso', 'trhlash', 'trarshq', 'tprasx', 'trasrhg', 'tratosh', 'tlmsh', 'tpasr', 'tivrash', 'traesv', 'ttmrash', 'tjahsh', 'itryash', 'tsgrash', 'tdashz', 'trvaqh', 'trdxh', 'mrahs', 'rstrash', 'trhgsh', 'tprksh', 'trqash', 'gtraeh', 'etrish', 'trasgi', 'trfsth', 'prkash', 'tjraph', 'gtrxash', 'tgasmh', 'tkrsah', 'wrasah', 'tualsh', 'ptrgsh', 'tcjrash', 'trgashe', 'trala', 'tragshj', 'araosh', 'tjrashr', 'rtasp', 'xravh', 'trnshm', ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
    if word in vocabulary:
        print(f"{word} is already correctly spelt")
        return 

    suggestions = edit1(word) or edit2(word) or [word]
    best_guesses = [w for w in suggestions if w in vocabulary]
    return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "lits"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
    print(corrections)
    probs = np.array([c[1] for c in corrections])
    best_ix = np.argmax(probs)
    correct = corrections[best_ix][0]
    print(f"{correct} is suggested for {word}")
# Out:
# lits is already correctly spelt

# %%
class SpellChecker(object):
    
    def __init__(self, corpus_file_path):
        with open(corpus_file_path, "r") as file:
            lines = file.readlines()
            words = []
            for line in lines:
                words += re.findall(r'\w+', line.lower())

        self.vocabs = set(words)
        self.word_counts = Counter(words)
        total_words = float(sum(self.word_counts.values()))
        self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

    def _level_one_edits(self, word):
        letters = string.ascii_lowercase
        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes = [l + r[1:] for l,r in splits if r]
        swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
        replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
        inserts = [l + c + r for l, r in splits for c in letters] 

        return set(deletes + swaps + replaces + inserts)

    def _level_two_edits(self, word):
        return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

    def check(self, word):
        candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
        valid_candidates = [w for w in candidates if w in self.vocabs]
        return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("./big.txt")

# %%
input_string=input("enter ur string:")

# %%
li=checker.check(input_string)

# %%
print(li)

# %%
data_set=[]
for i in li:
    data_set.append(i[0])

# %%
print(data_set)

# %%
neighbours={'z':['a','s','x'], 'x':['z','s','d','c'], 'c':['x','d','f','v'], 'v':['c','f','g','b'], 'b':['v','g','h','n'], 
            'n':['b','h','j','m'], 'm':['n','j','k'],

            'q':['w','s','a'], 'w':['q','a','s','e'], 'e':['w','s','d','r'], 'r':['e','d','f','g','t'], 't':['r','f','g','y'],
            'y':['t','g','h','u'], 'u':['y','h','j','i'], 'i':['u','j','k','o'], 'o':['i','k','l','p'], 'p':['o','l'],
            
            'a':['q','z','w','s','x'], 's':['a','w','e','d','x','z'], 'd':['s','e','r','f','c','x'], 'f':['d','r','t','g','v','c'],
            'g':['f','t','y','h','b','v'], 'h':['g','y','u','j','n','b'], 'j':['h','u','i','k','m','n'], 'k':['m','j','i','l'], 'l':['k','o','p']
            }

# %%
s=input_string
ans_list=[]
for i in range(len(s)):
    prefix=s[:i]
    suffix=s[i+1:]
    for v in neighbours[s[i]]:
        h = prefix + v + suffix
        if h in data_set:
            ans_list.append(h)

# %%
print(ans_list)
